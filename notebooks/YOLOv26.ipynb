# %%
# !nvidia-smi
# Out:
# Tue Jun 16 02:01:28 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 590.48.01              Driver Version: 590.48.01      CUDA Version: 13.1     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 5090        Off |   00000000:02:00.0 Off |                  N/A |
# |  0%   40C    P8             27W /  600W |    8295MiB /  32607MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolo26s.pt')

# %%
model.info()
# Out:
# YOLO26s summary: 260 layers, 10,009,784 parameters, 0 gradients, 22.8 GFLOPs
# (260, 10009784, 0, 22.838476800000002)

# %%
# !cat ../Final_v26_det/data.yaml
# Out:
# train: ./train/images
# val: ./valid/images
# test: ./test/images
#
# nc: 40
# names:
# - 5PN77-67001
# - W9078-67001
# - W9077-67001
# - 6SB85-67001
# - JC96-13015A
# - 5PN66-67001
# - 5PN73-67003
# - 933853-011
# - 5RC00-67001
# - 6CF14-67011
# - JC97-05149A
# - 5QK42-60104
# - 5PN80-67002
# - JC44-00150C
# - JC44-00240C
# - 5QK39-67002
# - 5QK08-67014
# - JC44-00236C
# - 5QK08-67011
# - 5QK08-67012
# - 5QK03-50003
# - JC90-01856A
# - JC95-02247A
# - 6ER04-61001
# - 8GS05-60128
# - 0604-001381
# - 0604-001490
# - JC93-01850A
# - JC31-00123C
# - JC93-01659A
# - 3SJ00-60110
# - JC93-00336A
# - SS216-80501
# - JC31-00078A
# - JC31-00198A
# - JC31-00154A
# - JC93-01019A
# - JC93-01467A
# - JC93-00466A
# - 5QJ90-40002

# %%
# !cat ../Final_v26_det/distribution.txt
# Out:
# �Class              Train            Val             Test
# --------------------------------------------------------------
# 0             2165( 2.72%)       590( 2.71%)       332( 2.84%)
# 1              946( 1.19%)       256( 1.18%)       124( 1.06%)
# 2              779( 0.98%)       169( 0.78%)       171( 1.46%)
# 3             1733( 2.18%)       500( 2.30%)       208( 1.78%)
# 4             1406( 1.77%)       331( 1.52%)       208( 1.78%)
# 5             1492( 1.87%)       360( 1.65%)       251( 2.15%)
# 6             1031( 1.29%)       264( 1.21%)       139( 1.19%)
# 7             3067( 3.85%)       895( 4.11%)       427( 3.66%)
# 8             2712( 3.41%)       717( 3.29%)       397( 3.40%)
# 9             2560( 3.22%)       686( 3.15%)       374( 3.20%)
# 10            1729( 2.17%)       564( 2.59%)       307( 2.63%)
# 11            1988( 2.50%)       519( 2.38%)       275( 2.36%)
# 12            1639( 2.06%)       383( 1.76%)       243( 2.08%)
# ...

# %%
model = YOLO("./runs/detect/train-5/weights/last.pt")

# %%
results = model.train(resume=True)
# Out:
# New https://pypi.org/project/ultralytics/8.4.68 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.56 🚀 Python-3.10.12 torch-2.12.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5090, 32112MiB)
# ...

# %%
from IPython.display import Image, display
image_path = "../YOLOv26/runs/detect/train-5/BoxF1_curve.png"
display(Image(filename=image_path))

# %%
image_path = "../YOLOv26/runs/detect/train-5/BoxP_curve.png"
display(Image(filename=image_path))

# %%
image_path = "../YOLOv26/runs/detect/train-5/BoxPR_curve.png"
display(Image(filename=image_path))

# %%
image_path = "../YOLOv26/runs/detect/train-5/BoxR_curve.png"
display(Image(filename=image_path))

# %%
image_path = "../YOLOv26/runs/detect/train-5/confusion_matrix.png"
display(Image(filename=image_path))

# %%
image_path = "../YOLOv26/runs/detect/train-5/labels.jpg"
display(Image(filename=image_path))

# %%
image_path = "../YOLOv26/runs/detect/train-5/results.png"
display(Image(filename=image_path))
