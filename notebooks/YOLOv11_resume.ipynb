# %%
# !nvidia-smi
# Out:
# Tue Jun  9 05:14:20 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 590.48.01              Driver Version: 590.48.01      CUDA Version: 13.1     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 5090        Off |   00000000:02:00.0 Off |                  N/A |
# |  0%   41C    P8             26W /  600W |    8295MiB /  32607MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from ultralytics import YOLO

# %%
model = YOLO('../YOLOv11/runs/detect/train-12/weights/last.pt')

# %%
model.info()
# Out:
# YOLO11s summary: 182 layers, 9,443,272 parameters, 0 gradients, 21.6 GFLOPs
# (182, 9443272, 0, 21.6323584)

# %%
# !cat ../Final/data.yaml
# Out:
# train: ./train/images
# val: ./valid/images
# test: ./test/images
#
# nc: 40
# names:
# - 5PN77-67001
# - W9078-67001
# - W9077-67001
# - 6SB85-67001
# - JC96-13015A
# - 5PN66-67001
# - 5PN73-67003
# - 933853-011
# - 5RC00-67001
# - 6CF14-67011
# - JC97-05149A
# - 5QK42-60104
# - 5PN80-67002
# - JC44-00150C
# - JC44-00240C
# - 5QK39-67002
# - 5QK08-67014
# - JC44-00236C
# - 5QK08-67011
# - 5QK08-67012
# - 5QK03-50003
# - JC90-01856A
# - JC95-02247A
# - 6ER04-61001
# - 8GS05-60128
# - 0604-001381
# - 0604-001490
# - JC93-01850A
# - JC31-00123C
# - JC93-01659A
# - 3SJ00-60110
# - JC93-00336A
# - SS216-80501
# - JC31-00078A
# - JC31-00198A
# - JC31-00154A
# - JC93-01019A
# - JC93-01467A
# - JC93-00466A
# - 5QJ90-40002

# %%
# !cat ../Final/distribution.txt
# Out:
# �Class              Train            Val             Test
# --------------------------------------------------------------
# 0             2449( 2.49%)       659( 2.46%)       339( 2.37%)
# 1             3349( 3.40%)       929( 3.47%)       466( 3.25%)
# 2             1581( 1.61%)       404( 1.51%)       305( 2.13%)
# 3             1923( 1.95%)       560( 2.09%)       247( 1.72%)
# 4             1548( 1.57%)       355( 1.33%)       227( 1.58%)
# 5             1643( 1.67%)       397( 1.48%)       291( 2.03%)
# 6             1475( 1.50%)       368( 1.37%)       198( 1.38%)
# 7             3453( 3.51%)      1005( 3.75%)       478( 3.34%)
# 8             3068( 3.11%)       806( 3.01%)       455( 3.18%)
# 9             2948( 2.99%)       811( 3.03%)       417( 2.91%)
# 10            1907( 1.94%)       627( 2.34%)       330( 2.30%)
# 11            2233( 2.27%)       601( 2.24%)       306( 2.14%)
# 12            1866( 1.89%)       426( 1.59%)       267( 1.86%)
# ...

# %%
result = model.train(data="../Final/data.yaml", 
                     epochs=40, 
                     imgsz=640,
                     mosaic=0.0,
                     mixup=0.0,
                     copy_paste=0.0,
                     degrees=0.0,
                     close_mosaic=0,
                    )
# Out:
# New https://pypi.org/project/ultralytics/8.4.62 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.56 🚀 Python-3.10.12 torch-2.12.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5090, 32112MiB)
# ...

# %%
from IPython.display import Image, display
image_path = "../YOLOv11/runs/detect/train-13/BoxF1_curve.png"
display(Image(filename=image_path))

# %%
image_path = "../YOLOv11/runs/detect/train-13/BoxP_curve.png"
display(Image(filename=image_path))

# %%
image_path = "../YOLOv11/runs/detect/train-13/BoxPR_curve.png"
display(Image(filename=image_path))

# %%
image_path = "../YOLOv11/runs/detect/train-12/BoxR_curve.png"
display(Image(filename=image_path))

# %%
image_path = "../YOLOv11/runs/detect/train-13/confusion_matrix.png"
display(Image(filename=image_path))

# %%
image_path = "../YOLOv11/runs/detect/train-13/labels.jpg"
display(Image(filename=image_path))

# %%
image_path = "../YOLOv11/runs/detect/train-13/results.png"
display(Image(filename=image_path))
